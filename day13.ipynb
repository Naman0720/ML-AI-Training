# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from skimage.transform import rotate

# %%
img1= cv2.imread('download (1).jpeg')
img2=cv2.imread('download.jpeg')
img1=img1[:135,:150]

# %%
img1.shape,img2.shape
# Out:
# ((150, 150, 3), (122, 135, 3))

# %%
def imshow(im):
    cv2.imshow('Preview',im)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
def showimg(im):
    plt.imshow(im[:,:,::-1])
    plt.show()

def imshow(im):
    cv2.imshow('Preview',im)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
added=cv2.add(img1,img2)
showimg(added)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 added=cv2.add(img1,img2)
#       2 showimg(added)
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:650: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'

# %%
subtracted=cv2.subtract(img1,img2)
showimg(subtracted)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 subtracted=cv2.subtract(img1,img2)
#       2 showimg(subtracted)
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:650: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'

# %%
*

# %%
img2_1=cv2.multiply(img1,2 * np.ones(img2.shape).astype('uint8'))
showimg(img2_1)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 img2_1=cv2.multiply(img1,2 * np.ones(img2.shape).astype('uint8'))
#       2 showimg(img2_1)
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:650: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'

# %%
img2_3 = cv2.resize(img1, (400,400), interpolation=cv2.INTER_CUBIC)
img2_3.shape
# Out:
# (400, 400, 3)

# %%
img2_3 = cv2.resize(img1,None,fx=2,fy=0.5, interpolation=cv2.INTER_CUBIC)
img2_3.shape
# Out:
# (84, 600, 3)

# %%
showimg(img2_3)

# %%
image_rotated= rotate(img1 ,angle=45,resize=True)
showimg(image_rotated)

# %%
from time import sleep
repeat=True
while True:
    for i in range (360):
        i=rotate(img1,angle=i,resize=True)
        cv2.imshow('',i)
        key = cv2.waitKey(1)
        if key==ord(' '):
            repeat=False
            break
        sleep(0.1)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 11
#       9             repeat=False
#      10             break
# ---> 11         sleep(0.1)
#      12 cv2.destroyAllWindows()
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
im_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
im_r = img1[:,:,2].copy()
img_g = img1[:,:,1].copy()
img_b = img1[:,:,0].copy()

# %%
plt.subplot(1,5,1)
plt.imshow(img1[:,:,::,-1]); plt.axis('off')

plt.subplot(1,5,2)
plt.imshow(im_gray,cmap='gray'); plt.axis('off')

plt.
